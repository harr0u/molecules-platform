# %%
import numpy
import pandas
import seaborn
import matplotlib.pyplot
from scipy import stats

# %%
# todo load file with generated data
# todo read it in pandas
# todo make distibution of pairwise distances (use scipy.spatial.distance engine is not responsible for this)
seaborn.set(color_codes=True)

x = numpy.random.normal(size=100)
seaborn.distplot(x);
